# %% [markdown]
# <a href="https://colab.research.google.com/github/ZoyaAfzal/Project4-Assignments/blob/main/Assignments%2001/online_class_projects_02_intermediate_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

# Control Flow for Console
print('High Low Game')

total_rounds = 5

def high_low():
  print('Welcome to the High Low Game.')
  print('You will be given a number and must guess whether it\'s higher or lower than the computer\'s number.')
  print('👉 Type **higher** or **lower** to make your guess.\nLet\'s begin!')
  print('----------------------------------------')

  score = 0

  for i in range(total_rounds):
    print('Round: ', i + 1)

    computer_number: int = random.randint(1, 100)
    your_number: int = random.randint(1, 100)
    print('your number is ', your_number)

    choice: str = input("Do you think your number is higher or lower than the computer's number!? ")
    higher_and_correct: bool = choice == 'higher' and your_number > computer_number
    lower_and_correct: bool = choice == 'lower' and your_number < computer_number

    if higher_and_correct or lower_and_correct:
      print('You were right! The computer\'s number was ', computer_number)
      score += 1
    else:
      print('You were wrong! The computer\'s number was ', computer_number)

    print('Your score is now: ', score)
    print()

  print('Game Over! Thanks for playing. Your final score is: ', score)

  if your_score == NUM_ROUNDS:
        print("Wow! You played perfectly!")
  elif your_score > NUM_ROUNDS // 2:
        print("Good job, you played really well!")
  else:
        print("Better luck next time!")

if __name__ == '__main__':
  high_low()
# Out:
# High Low Game
# Welcome to the High Low Game.
# You will be given a number and must guess whether it's higher or lower than the computer's number.
# 👉 Type **higher** or **lower** to make your guess.
# Let's begin!
# ----------------------------------------
# Round:  1
# your number is  93
# Do you think your number is higher or lower than the computer's number!? higher
# You were right! The computer's number was  76
# Your score is now:  1
#
# Round:  2
# your number is  21
# Do you think your number is higher or lower than the computer's number!? lower
# You were right! The computer's number was  51
# Your score is now:  2
#
# Round:  3
# your number is  7
# Do you think your number is higher or lower than the computer's number!? lower
# You were right! The computer's number was  58
# Your score is now:  3
#
# Round:  4
# your number is  46
# Do you think your number is higher or lower than the computer's number!? higher
# You were wrong! The computer's number was  51
# ...

# %%
# 🌍 Planetary Weight Calculator

def planetary_weight_calculator():
    print('🌍 Welcome to the Planetary Weight Calculator!')
    print('---------------------------------------------')

    try:
        earth_weight = float(input('⚖️  Enter your weight on Earth (kg): '))
    except ValueError:
        print("❌ Please enter a valid number for your weight.")
        return

    gravity_ratios = {
        "Mercury": 0.38,
        "Venus": 0.91,
        "Mars": 0.38,
        "Jupiter": 2.34,
        "Saturn": 1.06,
        "Uranus": 0.92,
        "Neptune": 1.19
    }

    print('\n🪐 Select a planet to see what you’d weigh there:')
    for planet in gravity_ratios:
        print(f'  - {planet}')

    planet_choice = input('\n Enter the name of the planet: ').title()

    if planet_choice in gravity_ratios:
        new_weight = earth_weight * gravity_ratios[planet_choice]
        print(f'\n On {planet_choice}, you would weigh approximately: {new_weight:.2f} kg')
    else:
        print(f" Sorry, '{planet_choice}' is not in our planetary list.")

    print('\n Thank you for using the calculator. Safe space travels! 🚀')


if __name__ == '__main__':
    planetary_weight_calculator()
# Out:
# 🌍 Welcome to the Planetary Weight Calculator!
# ---------------------------------------------
# ⚖️  Enter your weight on Earth (kg): 60
#
# 🪐 Select a planet to see what you’d weigh there:
#   - Mercury
#   - Venus
#   - Mars
#   - Jupiter
#   - Saturn
#   - Uranus
#   - Neptune
#
#  Enter the name of the planet: jupiter
#
#  On Jupiter, you would weigh approximately: 140.40 kg
#
#  Thank you for using the calculator. Safe space travels! 🚀

# %%
# Lists and Dicts

print('Problem #1: List Practice')

def main():
    fruit_list = ['apple', 'banana', 'orange', 'grape', 'pineapple']

    print(f"The list has {len(fruit_list)} fruits.")

    fruit_list.append('mango')

    print("🥭🍎 Updated fruit list:", fruit_list)

if __name__ == '__main__':
    main()
# Out:
# Problem #1: List Practice
# The list has 5 fruits.
# 🥭🍎 Updated fruit list: ['apple', 'banana', 'orange', 'grape', 'pineapple', 'mango']

# %%
# Lists and Dicts

print('🍇 Problem #2: Index Game 🍊')

def access_elements(fruit_list, index):
    """Returns the element at the given index in the list if it exists, otherwise returns Index out of range!"""
    if 0 <= index < len(fruit_list):
        return f'Element at index {index}: {fruit_list[index]}'
    return 'Index out of range!'

def modify_element(fruit_list, index, new_val):
    """Modifies the element at the given index in the list to the new value if exists, otherwise returns Index out of range!"""
    if 0 <= index < len(fruit_list):
        old_val = fruit_list[index]
        fruit_list[index] = new_val
        return f'Element "{old_val}" at index {index} modified to "{new_val}"'
    return 'Index out of range!'

def slice_list(fruit_list, start, end):
    """Returns a new list containing the elements from the start index to the end index!"""
    if 0 <= start < len(fruit_list) and 0 <= end <= len(fruit_list) and start < end:
        return f'Sliced list from index {start} to {end}: {fruit_list[start:end]}'
    return 'Invalid start or end index!'

def list_game():
    print('\nWelcome to the List Manipulation Game!')
    print('Fruits List Game 🍊🍇🍍')

    fruit_list = ['apple', 'banana', 'orange', 'grape', 'pineapple']

    while True:
        print('\n Current List:', fruit_list)

        print('\nWhat would you like to do?')
        print('1️⃣ Access an Element')
        print('2️⃣ Modify an Element')
        print('3️⃣ Slice the List')
        print('4️⃣ Quit')

        choice = input('👉 Enter your choice (1-4): ').strip()

        if choice == '1':
            try:
                index = int(input('Enter the index you want to access: '))
                print(access_elements(fruit_list, index))
            except ValueError:
                print('⚠️ Please enter a valid number.')
        elif choice == '2':
            try:
                index = int(input('Enter the index you want to modify: '))
                new_val = input('Enter the new value: ')
                print(modify_element(fruit_list, index, new_val))
            except ValueError:
                print('⚠️ Please enter a valid number.')
        elif choice == '3':
            try:
                start = int(input('Enter the start index: '))
                end = int(input('Enter the end index: '))
                print(slice_list(fruit_list, start, end))
            except ValueError:
                print('⚠️ Please enter valid numbers.')
        elif choice == '4':
            print('\n👋 Exiting the game. Thanks for playing! 🍉 See you again!')
            break
        else:
            print('🚫 Invalid choice. Please choose between 1 and 4.')

if __name__ == '__main__':
    list_game()
# Out:
# 🍇 Problem #2: Index Game 🍊
#
# Welcome to the List Manipulation Game!
# Fruits List Game 🍊🍇🍍
#
#  Current List: ['apple', 'banana', 'orange', 'grape', 'pineapple']
#
# What would you like to do?
# 1️⃣ Access an Element
# 2️⃣ Modify an Element
# 3️⃣ Slice the List
# 4️⃣ Quit
# 👉 Enter your choice (1-4): 1
# Enter the index you want to access: 2
# Element at index 2: orange
#
#  Current List: ['apple', 'banana', 'orange', 'grape', 'pineapple']
#
# What would you like to do?
# 1️⃣ Access an Element
# 2️⃣ Modify an Element
# 3️⃣ Slice the List
# 4️⃣ Quit
# 👉 Enter your choice (1-4): 2
# Enter the index you want to modify: 4
# Enter the new value: avacado
# Element "pineapple" at index 4 modified to "avacado"
#
#  Current List: ['apple', 'banana', 'orange', 'grape', 'avacado']
#
# What would you like to do?
# 1️⃣ Access an Element
# 2️⃣ Modify an Element
# 3️⃣ Slice the List
# 4️⃣ Quit
# 👉 Enter your choice (1-4): 3
# Enter the start index: 1
# Enter the end index: 4
# ...
